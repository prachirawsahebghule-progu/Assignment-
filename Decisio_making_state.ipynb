# %% [markdown]
# <a href="https://colab.research.google.com/github/prachirawsahebghule-progu/Assignment-/blob/main/Decisio_making_state.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num=int(input("enter any no"))
if num>5:
    print('Yes')
# Out:
# enter any no11
# Yes

# %%
num=int(input("enter any no"))
if num>5:
    print('Yes')
# Out:
# enter any no23
# Yes

# %%
num=int(input("enter any no"))
if num>0:
    print(num,'is positive')
else:
    print(num,'is negative')
# Out:
# enter any no23
# 23 is positive

# %%
num=int(input("enter any no"))
if num%2==0:
    print(num,'is even')
else:
     print(num,'is odd')
# Out:
# enter any no11
# 11 is odd

# %%
True+True+False
# Out:
# 2

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
num=int(input("enter any no"))
if num > 50:
    if num <100:
        print(num,"is between 50 and 100.")
    else:
        print(num,"is greater than 100.")
else:
    print(num,"is less than 50.")
# Out:
# enter any no12
# 12 is less than 50.

# %%
num=int(input("enter any no"))
if num==50 and num==100:
    print("Satisfied")
else:
    print("Not Satisfied")
# Out:
# enter any no22
# Not Satisfied

# %%
purchase_cost=int(input("Enter purchase cost:"))
selling_cost=int(input("Enter selling cost:"))
if selling_cost>purchase_cost:
    print("Profit",selling_cost-purchase_cost)
elif purchase_cost>selling_cost:
    print("Loss:",purchase_cost-selling_cost)
else:
    print("No profit and no loss")
# Out:
# Enter purchase cost:12
# Enter selling cost:23
# Profit 11

# %%
no1=int(input("Enter first number:"))
no2=int(input("Enter second number:"))
no3=int(input("Enter third number:"))
if no1>no2:
    if no1>no3:
        print(no1,'is greater')
    else:
        print(no3,'is greater')
else:
    if no2>no3:
        print(no2,"is greater")
    else:
        print(no3,"is greater")
# Out:
# Enter first number:1
# Enter second number:2
# Enter third number:3
# 3 is greater
