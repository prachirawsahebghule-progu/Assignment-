# %% [markdown]
# <a href="https://colab.research.google.com/github/prachirawsahebghule-progu/Assignment-/blob/main/25_may_ipybn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World')
# Out:
# Hello World

# %%
#add above -> A, below -> B frl-> x

# %%
num=56

# %%
num2=8

# %%
name='prachi'

# %%
#pass = 28

# %%
#pass = 3

# %%
pass

# %%
name
# Out:
# 'prachi'

# %%
a=10
b=0.4
c="prachi"

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# str

# %%
num=1234567890 ** 234
num
# Out:
# ...

# %%
num= 23e4

# %%
num
# Out:
# 230000.0

# %%
type(num)
# Out:
# float

# %%
#String

# %%
#sent=,

# %%
num1=int(input("Enter first number:"));
num2=int(input("Enter second number:"));
res=num1+num2;
print(res);
# Out:
# Enter first number:23
# Enter second number:11
# 34
