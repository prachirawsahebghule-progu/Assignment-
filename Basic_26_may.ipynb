# %% [markdown]
# <a href="https://colab.research.google.com/github/prachirawsahebghule-progu/Assignment-/blob/main/Basic_26_may.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="Pravin"

# %%
name.lower()
# Out:
# 'pravin'

# %%
name
# Out:
# 'Pravin'

# %%
name.upper()
# Out:
# 'PRAVIN'

# %%
name.title()
# Out:
# 'Pravin'

# %%
name="PrAvIn"

# %%
name.swapcase()
# Out:
# 'pRaViN'

# %%
name.islower()
# Out:
# False

# %%
name.isupper()
# Out:
# False

# %%
name.istitle()
# Out:
# False

# %%
name1="ok"
name2="123"
name3="ok123"

# %%
name1.isalpha()
# Out:
# True

# %%
name2.isalpha()
# Out:
# False

# %%
name3.isalpha()
# Out:
# False

# %%
name1.isdigit()
# Out:
# False

# %%
name2.isdigit()
# Out:
# True

# %%
name3.isdigit()
# Out:
# False

# %%
name3.isalnum()
# Out:
# True

# %%
name1.isalnum()
# Out:
# True

# %%
name="Pune"

# %%
name
# Out:
# 'Pune'

# %%
name.startswith("P")
# Out:
# True

# %%
name.startswith(" P")
# Out:
# False

# %%
name.startswith("Pune")
# Out:
# True

# %%
name.endswith("e ")
# Out:
# False

# %%
name.endswith("e")
# Out:
# True

# %%
name.lstrip()
# Out:
# 'Pune'

# %%
name.rstrip()
# Out:
# 'Pune'

# %%
name.strip()
# Out:
# 'Pune'

# %%
name
# Out:
# 'Pune'

# %%
len(name)
# Out:
# 4

# %%
name.replace('u','oo')
# Out:
# 'Poone'

# %%
#arithmatic

# %%
a=6
b=17

# %%
a+b
# Out:
# 23

# %%
a-b
# Out:
# -11

# %%
a*b
# Out:
# 102

# %%
a/b
# Out:
# 0.35294117647058826

# %%
a**b
# Out:
# 16926659444736

# %%
a//b
# Out:
# 0

# %%
b%a
# Out:
# 5

# %%
#assignment

# %%
z=5

# %%
z
# Out:
# 5

# %%
z+=3

# %%
z-=3

# %%
z
# Out:
# 5

# %%
z*=3

# %%
z
# Out:
# 15

# %%
#comparison

# %%
a
# Out:
# 6

# %%
b
# Out:
# 17

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
#logical Operator

# %%
a=True
b=False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %%
#Identity Operator

# %%
a=5
b=4

# %%
id(a),id(b)
# Out:
# (11645480, 11645448)

# %%
a is b
# Out:
# False

# %%
a=[3,4]
b=[3,4]

# %%
id(a),id(b)
# Out:
# (135068611322880, 135068611227648)

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
z=a

# %%
z is a
# Out:
# True

# %%
z
# Out:
# [3, 4]

# %%
a.append(10)
a
# Out:
# [3, 4, 10, 10]

# %%
z
# Out:
# [3, 4, 10, 10]

# %%
2**2**3
# Out:
# 256

# %%
2**3//2
# Out:
# 4

# %%
name="Geet"
marks=76.76

# %%
print("My name is",name,"and marks are",marks)
# Out:
# My name is Geet and marks are 76.76

# %%
print("My name is %s and marks are %i"%(name,marks))
# Out:
# My name is Geet and marks are 76

# %%
print(f"My name is {name} and marks are {marks}")
# Out:
# My name is Geet and marks are 76.76

# %%
#dir and help

# %%
dir(name,);

# %%
help(name.strip)
# Out:
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
#ascii

# %%
ord("a")
# Out:
# 97

# %%
ord("A")
# Out:
# 65

# %%
chr(65)
# Out:
# 'A'

# %%
chr(35)
# Out:
# '#'

# %%
#type casting

# %%
a=int(input("Enter number one:"))
b=int(input("Enter number two:"))
c=a+b
print("Addition =",c)
# Out:
# Enter number one:11
# Enter number two:23
# Addition = 34
